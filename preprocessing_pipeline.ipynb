# %%
# imports
import numpy as np
import pandas as pd
import statistics
from sklearn.preprocessing import FunctionTransformer, MinMaxScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.impute import SimpleImputer

# %%
#things that will be in the main Jupyter Notebook (load data, pre-pre-processing)
features = pd.read_csv("Data/training_set_features.csv")
labels = pd.read_csv("Data/training_set_labels.csv")

features.drop(['h1n1_concern', 'h1n1_knowledge', 'doctor_recc_h1n1',
               'opinion_h1n1_vacc_effective', 'opinion_h1n1_risk', 
               'opinion_h1n1_sick_from_vacc', 'hhs_geo_region', 
               'employment_industry', 'employment_occupation'], axis = 1, inplace = True)

labels.drop(['h1n1_vaccine', 'respondent_id'], axis = 1, inplace= True)
labels = np.ravel(labels, order = 'C')

# %%
X_train, X_test, y_train, y_test = train_test_split(features, labels, random_state = 42)
X_train
# Out:
#        respondent_id  behavioral_antiviral_meds  behavioral_avoidance  \
# 25194          25194                        0.0                   0.0
# 14006          14006                        0.0                   1.0
# 11285          11285                        0.0                   0.0
# 2900            2900                        0.0                   0.0
# 19083          19083                        1.0                   1.0
# ...              ...                        ...                   ...
# 21575          21575                        0.0                   0.0
# 5390            5390                        0.0                   0.0
# 860              860                        0.0                   1.0
# 15795          15795                        0.0                   1.0
# 23654          23654                        0.0                   0.0
#
#        behavioral_face_mask  behavioral_wash_hands  \
# 25194                   0.0                    0.0
# 14006                   0.0                    1.0
# 11285                   0.0                    0.0
# 2900                    0.0                    0.0
# 19083                   0.0                    1.0
# ...                     ...                    ...
# 21575                   0.0                    1.0
# 5390                    0.0                    1.0
# 860                     0.0                    0.0
# 15795                   0.0                    1.0
# 23654                   0.0                    1.0
#
#        behavioral_large_gatherings  behavioral_outside_home  \
# 25194                          0.0                      0.0
# 14006                          0.0                      0.0
# 11285                          0.0                      0.0
# 2900                           0.0                      0.0
# 19083                          1.0                      1.0
# ...                            ...                      ...
# 21575                          0.0                      0.0
# 5390                           0.0                      0.0
# 860                            0.0                      0.0
# 15795                          0.0                      0.0
# 23654                          0.0                      1.0
#
#        behavioral_touch_face  doctor_recc_seasonal  chronic_med_condition  \
# 25194                    0.0                   NaN                    0.0
# 14006                    0.0                   1.0                    1.0
# 11285                    0.0                   0.0                    0.0
# 2900                     0.0                   0.0                    1.0
# 19083                    1.0                   1.0                    NaN
# ...                      ...                   ...                    ...
# 21575                    1.0                   0.0                    0.0
# 5390                     1.0                   NaN                    0.0
# 860                      1.0                   0.0                    0.0
# 15795                    1.0                   1.0                    1.0
# 23654                    1.0                   0.0                    0.0
#
#        ...         education   race     sex             income_poverty  \
# 25194  ...          12 Years  White  Female                        NaN
# 14006  ...      Some College  White  Female                        NaN
# 11285  ...  College Graduate  White  Female  <= $75,000, Above Poverty
# 2900   ...  College Graduate  White    Male              Below Poverty
# 19083  ...               NaN  White  Female                        NaN
# ...    ...               ...    ...     ...                        ...
# 21575  ...      Some College  White    Male                  > $75,000
# 5390   ...      Some College  White    Male  <= $75,000, Above Poverty
# 860    ...          12 Years  White  Female  <= $75,000, Above Poverty
# 15795  ...  College Graduate  Black  Female                  > $75,000
# 23654  ...          12 Years  Black    Male  <= $75,000, Above Poverty
#
#        marital_status  rent_or_own   employment_status  \
# 25194     Not Married          Own  Not in Labor Force
# 14006         Married          NaN            Employed
# 11285     Not Married          Own            Employed
# 2900      Not Married          Own            Employed
# 19083             NaN          NaN                 NaN
# ...               ...          ...                 ...
# 21575     Not Married          Own  Not in Labor Force
# 5390      Not Married          Own          Unemployed
# 860           Married          Own            Employed
# 15795         Married          Own            Employed
# 23654     Not Married         Rent            Employed
#
#                      census_msa household_adults household_children
# 25194                   Non-MSA              1.0                1.0
# 14006  MSA, Not Principle  City              2.0                1.0
# 11285       MSA, Principle City              0.0                1.0
# 2900   MSA, Not Principle  City              0.0                0.0
# 19083  MSA, Not Principle  City              NaN                NaN
# ...                         ...              ...                ...
# 21575       MSA, Principle City              0.0                0.0
# 5390        MSA, Principle City              0.0                0.0
# 860                     Non-MSA              1.0                0.0
# 15795       MSA, Principle City              1.0                0.0
# 23654  MSA, Not Principle  City              0.0                0.0
#
# [20030 rows x 27 columns]

# %%
#create functions for preprocessing

#def features_drop(X_df):
#    X_df.drop(["h1n1_concern", "h1n1_knowledge", "doctor_recc_h1n1", "opinion_h1n1_vacc_effective", "opinion_h1n1_risk", "opinion_h1n1_sick_from_vacc", "hhs_geo_region", "employment_industry", "employment_occupation"], 
#              axis = 1, inplace = True)
#    return X_df

def replace_NAN_median(X_df):
    opinions = ['opinion_seas_vacc_effective', 'opinion_seas_risk', 'opinion_seas_sick_from_vacc', 'household_adults',
                'household_children']
    for column in opinions:
        X_df[column].replace(np.nan, X_df[column].median(), inplace = True)
    return X_df
        
def replace_NAN_mode(X_df):
    miss_cat_features = ['education', 'income_poverty', 'marital_status', 'rent_or_own', 'employment_status']
    for column in miss_cat_features:
        X_df[column].replace(np.nan, statistics.mode(X_df[column]), inplace = True)
    return X_df

# %%
# Instantiate transformers
#feat_drop = FunctionTransformer(features_drop)
NAN_median = FunctionTransformer(replace_NAN_median)
NAN_mode = FunctionTransformer(replace_NAN_mode)
col_transformer = ColumnTransformer(transformers=
    [("NAN_0", SimpleImputer(missing_values=np.nan, strategy='constant', fill_value = 0), 
    ['behavioral_antiviral_meds', 'behavioral_avoidance','behavioral_face_mask' ,
    'behavioral_wash_hands', 'behavioral_large_gatherings', 'behavioral_outside_home',
    'behavioral_touch_face', 'doctor_recc_seasonal', 'chronic_med_condition', 
    'child_under_6_months', 'health_worker', 'health_insurance']),
    
    ("scaler", MinMaxScaler(), ['opinion_seas_vacc_effective', 'opinion_seas_risk',
                                'opinion_seas_sick_from_vacc', 
                                'household_adults', 'household_children']),
     
    ("ohe", OneHotEncoder(), ['age_group','education', 'race', 'sex', 
                                'income_poverty', 'marital_status', 'rent_or_own',
                                'employment_status', 'census_msa'])],
     
    remainder="passthrough")

# %%
preprocessing_pipe = Pipeline(steps=[
    #("feat_drop", feat_drop),
    ("NAN_median", NAN_median), 
    ("NAN_mode", NAN_mode), 
    ("col_transformer", col_transformer),
    ("model", LogisticRegression(solver = 'liblinear'))
    ], verbose = True)

# %%
base_log_model = preprocessing_pipe.fit(X_train, y_train)
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# [Pipeline] ........ (step 1 of 4) Processing NAN_median, total=   0.0s
# [Pipeline] .......... (step 2 of 4) Processing NAN_mode, total=   0.0s
# [Pipeline] ... (step 3 of 4) Processing col_transformer, total=   0.1s
# [Pipeline] ............. (step 4 of 4) Processing model, total=   0.2s

# %%
base_log_model.score(X_test, y_test)
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# 0.7763965852927962

# %%
base_log_model.predict(X)
# Out:
# C:\Users\15164\anaconda3\envs\learn-env\lib\site-packages\pandas\core\series.py:4563: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().replace(
# array([0, 0, 1, ..., 1, 0, 1], dtype=int64)
